# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rutera = 'C:/Users/felip/OneDrive/Documentos/TUPED/3erAño/Visualizacion/data/ds_salaries.csv'
df = pd.read_csv(rutera)

# %%
df.head(20)
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2023               SE              FT  Principal Data Scientist
# 1        2023               MI              CT               ML Engineer
# 2        2023               MI              CT               ML Engineer
# 3        2023               SE              FT            Data Scientist
# 4        2023               SE              FT            Data Scientist
# 5        2023               SE              FT         Applied Scientist
# 6        2023               SE              FT         Applied Scientist
# 7        2023               SE              FT            Data Scientist
# 8        2023               SE              FT            Data Scientist
# 9        2023               SE              FT            Data Scientist
# 10       2023               SE              FT            Data Scientist
# 11       2023               SE              FT              Data Analyst
# ...

# %%
#df.groupby("job_title").agg({"salary_in_usd": "mean"}).sort_values(by="salary_in_usd", ascending=False) 
#explicar que hace el groupby y el agg: agrupa por job_title y calcula la mediana de salary_in_usd
#busco el valor "Data Architect" en job_title y me da el valor de salary_in_usd
df[df["job_title"] == "Analytics Engineer"]["salary_in_usd"].mean()
# Out:
# 152368.63106796116

# %%
#sacar promedio de todos los valores de salary_in_usd segun job_title y mostrarlos en un dataframe
promedio_salarios = df.groupby("job_title").agg({"salary_in_usd": "mean"}).sort_values(by="salary_in_usd", ascending=False)
#busco analytics engenieer en promedio_salarios
promedio_salarios.head(10)
# Out:
#                                     salary_in_usd
# job_title
# Data Science Tech Lead              375000.000000
# Cloud Data Architect                250000.000000
# Data Lead                           212500.000000
# Data Analytics Lead                 211254.500000
# Principal Data Scientist            198171.125000
# Director of Data Science            195140.727273
# Principal Data Engineer             192500.000000
# Machine Learning Software Engineer  192420.000000
# Data Science Manager                191278.775862
# Applied Scientist                   190264.482759

# %%
#contar la cantidad de valores unicos de empleados
df["employee_residence"].unique()
# Out:
# array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'PT', 'NL', 'CH',
#        'CF', 'FR', 'AU', 'FI', 'UA', 'IE', 'IL', 'GH', 'AT', 'CO', 'SG',
#        'SE', 'SI', 'MX', 'UZ', 'BR', 'TH', 'HR', 'PL', 'KW', 'VN', 'CY',
#        'AR', 'AM', 'BA', 'KE', 'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA',
#        'LT', 'BE', 'AS', 'IR', 'HU', 'SK', 'CN', 'CZ', 'CR', 'TR', 'CL',
#        'PR', 'DK', 'BO', 'PH', 'DO', 'EG', 'ID', 'AE', 'MY', 'JP', 'EE',
#        'HN', 'TN', 'RU', 'DZ', 'IQ', 'BG', 'JE', 'RS', 'NZ', 'MD', 'LU',
#        'MT'], dtype=object)

# %%
#quiero ver los valores de salary_in_usd y que el job_title sea "Data Architect"
DA = df[df["job_title"] == "Data Science Manager"]["salary_in_usd"]
#sacar el promedio de salary_in_usd de Data Architect
DA.mean()
# Out:
# 191278.77586206896

# %%
#escribir en un csv con el nombre de "ds_salaries_cleaned.csv"
df.to_csv("C:/Users/felip/OneDrive/Documentos/TUPED/3erAño/Visualizacion/data/ds_salaries_cleaned.csv", index=False)

# %%
#quiero calcular el promedio de salary_in_usd por job_title
df.groupby("job_title").agg({"salary_in_usd": "mean"}).sort_values(by="salary_in_usd", ascending=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rutera = 'C:/Users/felip/OneDrive/Documentos/TUPED/3erAño/Visualizacion/data/netflix.csv'
df = pd.read_csv(rutera)

# %%
print(df.describe())
# Out:
#        imdb_score     runtime         year
# count  583.000000  583.000000   583.000000
# mean     6.275129   93.490566  2018.934820
# std      0.976678   27.706665     1.474598
# min      2.500000    4.000000  2014.000000
# 25%      5.700000   86.000000  2018.000000
# 50%      6.400000   97.000000  2019.000000
# 75%      7.000000  107.500000  2020.000000
# max      9.000000  209.000000  2021.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       583 non-null    object
#  1   genre       583 non-null    object
#  2   language    583 non-null    object
#  3   imdb_score  583 non-null    float64
#  4   premiere    583 non-null    object
#  5   runtime     583 non-null    int64
#  6   year        583 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 32.0+ KB
# None

# %%
#cuantas filas o registros tiene df
print(df.shape[0])
# Out:
# 583

# %%
print(df.head())
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %%
todosGeneros = (df['genre'].unique())
len(todosGeneros)
print(todosGeneros)

# %%
#cuento la cantidad de valores que contiene "drama"
cont_drama = df[df['genre'].str.contains('Drama')]
print(cont_drama)
# #ahora modifico la variable genre para que solo tenga los generos que contienen "Drama"
# df['genre'] = df['genre'].str.replace('Drama', 'Drama')

# #ahora encuentro todos los generos que tienen "Drama" en su nombre
# (df['genre'].unique())
# Out:
# 83

# %%
#hago un bucle for que recorra todas las filas (para abajo) de la columna "genre" y busque si tiene "Drama" en su nombre
#si lo tiene, lo reemplaza por "Drama"
for i in range(df['genre'].shape[0]):
    if i str.contains('Drama'):
        df['genre'][i] = 'Drama'

# %%
genero = pd.DataFrame(df['genre'].value_counts())
genero.plot(kind='bar', figsize=(20, 5))
# Out:
# <Axes: xlabel='genre'>

# %%
#ahora me quiero quedar con los primeros 9 valores mas altos del grafico
genero = genero.head(9)
genero.plot(kind='bar', figsize=(20, 5))
# Out:
# <Axes: xlabel='genre'>

# %%
#ahora quiero hacer un grafico que cruce a el valor documentary con year
documentary = df[df['genre'] == 'Documentary']
documentary = pd.DataFrame(documentary['year'].value_counts())
documentary.plot(kind='bar', figsize=(20, 5))
# Out:
# <Axes: xlabel='year'>
